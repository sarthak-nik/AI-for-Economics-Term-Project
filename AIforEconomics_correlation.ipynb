# %%
# !pip install yfinance pandas mplfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.1 MB/s eta 0:00:00
# ...

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import pandas_datareader as web
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn

# %% [markdown]
# **IT SECTOR ANALYSIS**

# %%
symbols_list = ['TCS.NS', 'INFY.NS', 'HCLTECH.NS', 'WIPRO.NS', 'LTIM.NS', 'TECHM.NS']
#array to store prices
symbols=[]

for ticker in symbols_list:
    r=yf.download(ticker, start="2019-11-01", end ="2023-11-01" )
    # add a symbol column
    r['Symbol'] = ticker
    symbols.append(r)

# concatenate into df
df = pd.concat(symbols)
df = df.reset_index()
df = df[['Date', 'Close', 'Symbol']]
# df.head()
df_pivot=df.pivot('Date','Symbol','Close').reset_index()
# df_pivot.head()
corr_df = df_pivot.corr(method='pearson')
#reset symbol as index (rather than 0-X)
corr_df.head().reset_index()
#del corr_df.index.name
corr_df.head(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# <ipython-input-34-a09fd9d84880>:16: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot=df.pivot('Date','Symbol','Close').reset_index()
# <ipython-input-34-a09fd9d84880>:18: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_df = df_pivot.corr(method='pearson')
# ...

# %%
plt.figure(figsize=(13, 8))
seaborn.heatmap(corr_df, annot=True, cmap='RdYlGn')
plt.figure()

# %% [markdown]
# **BANK SECTOR ANALYSIS**

# %%
symbols_list = ['HDFCBANK.NS', 'ICICIBANK.NS', 'SBIN.NS', 'KOTAKBANK.NS', 'AXISBANK.NS', 'INDUSINDBK.NS']
#array to store prices
symbols=[]

for ticker in symbols_list:
    r=yf.download(ticker, start="2019-11-01", end ="2023-11-01" )
    # add a symbol column
    r['Symbol'] = ticker
    symbols.append(r)

# concatenate into df
df = pd.concat(symbols)
df = df.reset_index()
df = df[['Date', 'Close', 'Symbol']]
# df.head()
df_pivot=df.pivot('Date','Symbol','Close').reset_index()
# df_pivot.head()
corr_df = df_pivot.corr(method='pearson')
#reset symbol as index (rather than 0-X)
corr_df.head().reset_index()
#del corr_df.index.name
corr_df.head(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# <ipython-input-36-98f0ba4e13c0>:16: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot=df.pivot('Date','Symbol','Close').reset_index()
# <ipython-input-36-98f0ba4e13c0>:18: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_df = df_pivot.corr(method='pearson')
# Symbol         AXISBANK.NS  HDFCBANK.NS  ICICIBANK.NS  INDUSINDBK.NS  \
# ...

# %%
plt.figure(figsize=(13, 8))
seaborn.heatmap(corr_df, annot=True, cmap='RdYlGn')
plt.figure()

# %% [markdown]
# **FMCG SECTOR ANALYSIS**

# %%
symbols_list = ['HINDUNILVR.NS', 'ITC.NS', 'NESTLEIND.NS', 'VBL.NS', 'BRITANNIA.NS', 'GODREJCP.NS']
#array to store prices
symbols=[]

for ticker in symbols_list:
    r=yf.download(ticker, start="2019-11-01", end ="2023-11-01" )
    # add a symbol column
    r['Symbol'] = ticker
    symbols.append(r)

# concatenate into df
df = pd.concat(symbols)
df = df.reset_index()
df = df[['Date', 'Close', 'Symbol']]
# df.head()
df_pivot=df.pivot('Date','Symbol','Close').reset_index()
# df_pivot.head()
corr_df = df_pivot.corr(method='pearson')
#reset symbol as index (rather than 0-X)
corr_df.head().reset_index()
#del corr_df.index.name
corr_df.head(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# <ipython-input-38-fdb4d828f618>:16: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot=df.pivot('Date','Symbol','Close').reset_index()
# <ipython-input-38-fdb4d828f618>:18: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_df = df_pivot.corr(method='pearson')
# Symbol         BRITANNIA.NS  GODREJCP.NS  HINDUNILVR.NS    ITC.NS  \
# ...

# %%
plt.figure(figsize=(13, 8))
seaborn.heatmap(corr_df, annot=True, cmap='RdYlGn')
plt.figure()

# %% [markdown]
# **AUTOMOBILE SECTOR ANALYSIS**

# %%
symbols_list = ['MARUTI.NS', 'TATAMOTORS.NS', 'M&M.NS', 'BAJAJ-AUTO.NS', 'EICHERMOT.NS', 'TVSMOTOR.NS']
#array to store prices
symbols=[]

for ticker in symbols_list:
    r=yf.download(ticker, start="2019-11-01", end ="2023-11-01" )
    # add a symbol column
    r['Symbol'] = ticker
    symbols.append(r)

# concatenate into df
df = pd.concat(symbols)
df = df.reset_index()
df = df[['Date', 'Close', 'Symbol']]
# df.head()
df_pivot=df.pivot('Date','Symbol','Close').reset_index()
# df_pivot.head()
corr_df = df_pivot.corr(method='pearson')
#reset symbol as index (rather than 0-X)
corr_df.head().reset_index()
#del corr_df.index.name
corr_df.head(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# <ipython-input-44-ebcb6d9c0d1b>:16: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot=df.pivot('Date','Symbol','Close').reset_index()
# <ipython-input-44-ebcb6d9c0d1b>:18: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_df = df_pivot.corr(method='pearson')
# Symbol         BAJAJ-AUTO.NS  EICHERMOT.NS    M&M.NS  MARUTI.NS  \
# ...

# %%
plt.figure(figsize=(13, 8))
seaborn.heatmap(corr_df, annot=True, cmap='RdYlGn')
plt.figure()
